# %% [markdown]
# ## Mi pc es una basura...?

# %% [markdown]
# ## before

# %%
from IPython import display as dp

# %%
dp.Image("foto1cpu.png")

# %%
dp.Image("foto2cpu.png")

# %%
dp.Image("foto3cpu.png")

# %%
dp.Image("foto4cpu.png")

# %% [markdown]
# ## after

# %%
def fib (n):
    if n in{0,1}:
        return 1
    else:
        return(fib(n-1)+fib(n-2))

# %%
fib(50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 fib(50)
#
# Cell In [18], line 5, in fib(n)
#       3     return 1
#       4 else:
# ----> 5     return(fib(n-1)+fib(n-2))
#
# Cell In [18], line 5, in fib(n)
#       3     return 1
#       4 else:
# ----> 5     return(fib(n-1)+fib(n-2))
#
#     [... skipping similar frames: fib at line 5 (33 times)]
#
# Cell In [18], line 5, in fib(n)
#       3     return 1
#       4 else:
# ----> 5     return(fib(n-1)+fib(n-2))
#
# KeyboardInterrupt:

# %%
dp.Image("foto5cpu.png")

# %%
dp.Image("foto6cpu.png")

# %%
dp.Image("foto7cpu.png")

# %%
dp.Image("foto8cpu.png")

# %%
import threading as th

# %%
import multiprocessing as mp

# %%
mp.Pool
# Out:
# <bound method BaseContext.Pool of <multiprocessing.context.DefaultContext object at 0x000002815567ADA0>>
